# %% [markdown]
# <a href="https://colab.research.google.com/github/EnzoE-2026/Data-Analysis-Science-Healthcare/blob/main/GIS_crim_rate_proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#stats: cluster sampling


#cincinnati crime rate data set (accesbile via api, and .csv file. >>>>>>> do both methods)

#api
    # import requests
    # import csv
    # url = "https://data.cincinnati-oh.gov/resource/7aqy-xrv9.json"
    # response = requests.get(url)
    # decoded = response.content.decode("utf-8")
    #
    # reader = csv.reader(decoded.splitlines())
    # rows = list(reader)
    #
    # for row in rows:
    #     print(row)


#cincinnati crime rate data set (accesbile via api, and .csv file. >>>>>>> do both methods)

#api
    # import requests
    # import csv
    # url = "https://data.cincinnati-oh.gov/resource/7aqy-xrv9.json"
    # response = requests.get(url)
    # decoded = response.content.decode("utf-8")
    #
    # reader = csv.reader(decoded.splitlines())
    # rows = list(reader)
    #
    # for row in rows:
    #     print(row)



#csv -- main method
import geopandas as gpd
import pandas as pd

df = pd.read_csv("df_export.csv")  # whitespace-delimited
print(df.columns)


# gdf = gpd.GeoDataFrame(
#     df,
#     geometry = gpd.points_from_xy(df.lon, df.lat),
#     crs="EPSG:4326"
# )
# gdf.to_file("output.geojson", driver="GeoJSON")
#csv -- main method
import geopandas as gpd
import pandas as pd

df = pd.read_csv("df_export.csv")  # whitespace-delimited
df.columns


# gdf = gpd.GeoDataFrame(
#     df,
#     geometry = gpd.points_from_xy(df.lon, df.lat),
#     crs="EPSG:4326"
# )
# gdf.to_file("output.geojson", driver="GeoJSON")
# Out:
# Index(['INCIDENT_NO', 'DateReported', 'DateFrom', 'DateTo', 'BEAT', 'CLSD',
#        'STARS_Category', 'DAY_OF_WEEK', 'CPD_Neighborhood', 'Hour_From',
#        'Hour_To', 'type', 'SNA_Neighborhood', 'CC_Neighborhood', 'ADDRESS_X',
#        'LATITUDE_X', 'LONGITUDE_X'],
#       dtype='object')

# %%
df
# Out:
#            INCIDENT_NO             DateReported                 DateFrom  \
# 0      2024-INC-000014  2024 Jun 03 07:54:00 AM  2024 Jun 03 05:00:00 AM
# 1      2024-INC-000019  2024 Jun 03 07:13:00 AM  2024 Jun 02 07:11:00 PM
# 2      2024-INC-000041  2024 Jun 03 01:08:00 PM  2024 Jun 02 12:00:00 AM
# 3      2024-INC-000051  2024 Jun 03 11:59:00 AM  2024 Jun 02 02:30:00 PM
# 4      2024-INC-000056  2024 Jun 03 12:28:00 PM  2024 Jun 03 06:00:00 AM
# ...                ...                      ...                      ...
# 49504       269C000219  2026 May 08 07:24:00 AM  2026 May 07 07:00:00 PM
# 49505       269C000224  2026 May 09 06:31:00 PM  2026 May 05 02:26:00 PM
# 49506       269C000226  2026 May 09 09:15:00 PM  2026 May 09 07:35:00 PM
# 49507       269C000227  2026 May 10 11:24:00 AM  2026 May 09 12:00:00 AM
# 49508       269C000232  2026 May 11 06:16:00 PM  2026 May 10 08:00:00 PM
#
#                         DateTo  BEAT                     CLSD  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49509 entries, 0 to 49508
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INCIDENT_NO       49509 non-null  object
#  1   DateReported      49509 non-null  object
#  2   DateFrom          49505 non-null  object
#  3   DateTo            49505 non-null  object
#  4   BEAT              49315 non-null  object
#  5   CLSD              49256 non-null  object
#  6   STARS_Category    49509 non-null  object
#  7   DAY_OF_WEEK       49509 non-null  object
#  8   CPD_Neighborhood  49315 non-null  object
#  9   Hour_From         49505 non-null  float64
#  10  Hour_To           49505 non-null  float64
#  11  type              49509 non-null  object
#  12  SNA_Neighborhood  49263 non-null  object
#  13  CC_Neighborhood   49300 non-null  object
#  14  ADDRESS_X         48691 non-null  object
#  15  LATITUDE_X        49390 non-null  float64
# ...
